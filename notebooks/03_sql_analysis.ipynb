# %% [markdown]
# Stage 3: SQL Analytics (DuckDB)
#
# **Description:** In this stage, we simulate a modern **Data Lakehouse** architecture. Instead of loading data into a traditional heavy database (like PostgreSQL), we use **DuckDB** — an in-process OLAP SQL engine. This allows us to run complex SQL queries directly on our optimized `Parquet` files.
#
# **Business Objectives:**
# 1. **Market Segmentation:** Analyze average pricing and nutrient density across the ML-generated clusters.
# 2. **Value Analysis:** Identify the top 3 "Best Value" products in each category using Window Functions.
# 3. **Inventory Risk:** Detect premium products with critical stock levels to generate alerts for the Supply Chain team.
#
# **Tech Stack:** `DuckDB`, `SQL`, `Pandas`

# %%
import duckdb
import pandas as pd

# --- Configuration ---
# Connecting to the "Gold Layer" (Cleaned & Enriched Data)
INPUT_FILE = '../data/processed/supplements_enriched.parquet'

print("Connecting to Data Lakehouse via DuckDB...")

# Initialize in-memory database connection
con = duckdb.connect()

# ==============================================================================
# REPORT 1: Market Segmentation Overview
# Business Question: "How does pricing and potency differ across our customer segments?"
# ==============================================================================
print("\n--- [Report 1] Market Segmentation Overview ---")

query_overview = f"""
SELECT 
    segment_name,
    COUNT(*) as total_products,
    ROUND(AVG(price_eur), 2) as avg_price_eur,
    ROUND(AVG(vitamin_c_mg), 0) as avg_vit_c_mg,
    ROUND(AVG(magnesium_mg), 0) as avg_magnesium_mg
FROM '{INPUT_FILE}'
GROUP BY segment_name
ORDER BY avg_price_eur DESC
"""

df_overview = con.execute(query_overview).df()
display(df_overview)

# ==============================================================================
# REPORT 2: Best Value Products (Top 3 per Category)
# Business Question: "Which products offer the most active ingredients per Euro?"
# Technical Skill: Window Functions (ROW_NUMBER)
# ==============================================================================
print("\n--- [Report 2] Top 3 'Best Value' Products per Category ---")

query_ranking = f"""
WITH RankedProducts AS (
    SELECT 
        product_name,
        category,
        price_eur,
        price_per_1000mg,
        -- Partition by Category to restart ranking for each product type
        ROW_NUMBER() OVER (PARTITION BY category ORDER BY price_per_1000mg ASC) as rank_id
    FROM '{INPUT_FILE}'
)
SELECT 
    category,
    product_name,
    price_eur,
    ROUND(price_per_1000mg, 2) as eur_per_1000mg_active
FROM RankedProducts
WHERE rank_id <= 3
ORDER BY category, eur_per_1000mg_active
"""

df_ranking = con.execute(query_ranking).df()
display(df_ranking)

# ==============================================================================
# REPORT 3: Inventory Risk Alert
# Business Question: "Which Premium products are running low on stock?"
# ==============================================================================
print("\n--- [Report 3] Low Stock Alert (Premium Segment) ---")

query_stock = f"""
SELECT 
    product_name,
    stock_level,
    price_eur,
    last_updated
FROM '{INPUT_FILE}'
WHERE segment_name LIKE '%Premium%' 
  AND stock_level < 20
ORDER BY stock_level ASC
LIMIT 10
"""

df_stock = con.execute(query_stock).df()
display(df_stock)
# Out:
# Connecting to Data Lakehouse via DuckDB...
#
# --- [Report 1] Market Segmentation Overview ---
#            segment_name  total_products  avg_price_eur  avg_vit_c_mg  \
# 0  High-Potency Premium             813          50.54         242.0
# 1   Balanced / Standard             553          29.84         333.0
# 2     Budget Essentials             631          28.37         178.0
#
#    avg_magnesium_mg
# 0             147.0
# 1             178.0
# 2             123.0
# --- [Report 2] Top 3 'Best Value' Products per Category ---
#         category                  product_name  price_eur  \
# 0      Magnesium     NutriLife Magnesium Ultra      16.29
# 1      Magnesium        NutriLife Omega-3 Plus      15.63
# 2      Magnesium   NutriLife Multivitamin Plus      16.39
# 3   Multivitamin       NutriLife Omega-3 Ultra      15.50
# 4   Multivitamin       NutriLife Magnesium Pro      16.16
# 5   Multivitamin         NutriLife Omega-3 Pro      16.33
# 6        Omega-3  NutriLife Multivitamin Basic      56.29
# 7        Omega-3     NutriLife Vitamin C Basic      15.18
# 8        Omega-3       NutriLife Omega-3 Basic      15.41
# 9      Vitamin C           NutriLife Zinc Plus      15.95
# 10     Vitamin C        NutriLife Omega-3 Plus      17.25
# 11     Vitamin C       NutriLife Vitamin C Pro      15.91
# 12    Vitamin D3        NutriLife Omega-3 Plus      15.50
# 13    Vitamin D3   NutriLife Multivitamin Plus      16.19
# 14    Vitamin D3        NutriLife Omega-3 Plus      17.51
# 15          Zinc    NutriLife Multivitamin Pro      17.01
# 16          Zinc       NutriLife Magnesium Pro      15.20
# 17          Zinc     NutriLife Vitamin C Ultra      19.87
#
#     eur_per_1000mg_active
# 0                   26.95
# 1                   27.74
# 2                   28.29
# 3                   25.25
# 4                   26.83
# 5                   27.57
# 6                -1628.19
# 7                   24.92
# 8                   30.93
# 9                   26.03
# 10                  29.71
# 11                  30.73
# 12                  28.63
# 13                  29.67
# 14                  30.09
# 15                  29.14
# 16                  29.21
# 17                  30.24
# --- [Report 3] Low Stock Alert (Premium Segment) ---
#                    product_name  stock_level  price_eur  \
# 0         NutriLife Omega-3 Pro            0      46.61
# 1      NutriLife Magnesium Plus            1      53.86
# 2     NutriLife Vitamin C Ultra            1      56.70
# 3       NutriLife Magnesium Pro            2      52.70
# 4       NutriLife Magnesium Pro            2      49.29
# 5  NutriLife Multivitamin Ultra            3      43.07
# 6          NutriLife Zinc Ultra            3      48.70
# 7     NutriLife Vitamin D3 Plus            3      57.41
# 8      NutriLife Magnesium Plus            3      47.67
# 9       NutriLife Omega-3 Basic            4      47.51
#
#                 last_updated
# 0 2025-12-06 21:32:33.602978
# 1 2025-12-17 21:32:33.602934
# 2 2025-12-08 21:32:33.603041
# 3 2025-12-27 21:32:33.602116
# 4 2025-12-21 21:32:33.602580
# 5 2025-12-26 21:32:33.601867
# 6 2025-12-11 21:32:33.602682
# 7 2025-12-16 21:32:33.602726
# 8 2025-12-06 21:32:33.603792
# 9 2025-12-08 21:32:33.603242
